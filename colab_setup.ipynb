# %%
! python run.py --mode show

from IPython.display import clear_output
from IPython.display import Image

clear_output()
Image(filename='./output.jpg')

# %%
! python run.py --mode recons
# Out:
# 2.5.0
# RECONSTRUCTION STARTS
# Epoch 00000: PSNR  9.311 : Max PSNR  9.311
#
#
# Epoch 00001: PSNR  6.948 : Max PSNR  9.311
# Epoch 00002: PSNR -9.240 : Max PSNR  9.311
# Epoch 00003: PSNR  3.037 : Max PSNR  9.311
# Epoch 00004: PSNR  9.336 : Max PSNR  9.336
# Epoch 00005: PSNR  9.527 : Max PSNR  9.527
#
#
# Epoch 00006: PSNR  9.330 : Max PSNR  9.527
# Epoch 00007: PSNR  9.250 : Max PSNR  9.527
# Epoch 00008: PSNR  9.232 : Max PSNR  9.527
# Epoch 00009: PSNR  9.244 : Max PSNR  9.527
# W0809 00:28:48.064049  1772 image.py:721] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0809 00:28:48.095077  1772 image.py:721] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0809 00:28:48.122102  1772 image.py:721] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
Image(filename='./recons.jpg')
